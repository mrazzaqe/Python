# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
traffic = pd.read_csv("traffic_data.csv")
traffic.head()
# Out:
#     Month  Total Traffic (GB)
# 0  18-Jul              583884
# 1  18-Aug             1031401
# 2  18-Sep             1288568
# 3  18-Oct             1497199
# 4  18-Nov             1621504

# %%
type(traffic)
# Out:
# pandas.core.frame.DataFrame

# %%
traffic=pd.read_csv("Traffic_data.csv", index_col=[0],parse_dates=True, squeeze=True)
type(traffic)
traffic.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
traffic.plot(style='k.')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
traffic.size
traffic.describe()
# Out:
# count    4.000000e+01
# mean     8.151913e+06
# std      5.792793e+06
# min      5.838840e+05
# 25%      2.951979e+06
# 50%      7.700517e+06
# 75%      1.144204e+07
# max      2.035313e+07
# Name: Total Traffic (GB), dtype: float64

# %%
traffic_ma=traffic.rolling(window=15).mean()
traffic_ma.plot()
# Out:
# <AxesSubplot:xlabel='Month'>
