# %%
from bs4 import BeautifulSoup
import requests
url ="https://www.shwapno.com/pages/half-price-offers/pgid-1431195.aspx"
req = requests.get(url)
soup = BeautifulSoup(req.text, "html.parser")
print(soup.title)
# Out:
# <title>
# 	Half Price Offers
# </title>

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://www.shwapno.com/Registration/Login.aspx?ReturnUrl=https://www.shwapno.com
# https://www.shwapno.com/Registration/UserRegistration.aspx?ReturnUrl=RequestUrl
# /pages/help-line-number/pgid-1233762.aspx
# #!
# javascript:void(0)
# /pages/about-us/pgid-1222234.aspx
# /pages/outlet-locations/pgid-1232028.aspx
# /pages/privacy-policy/pgid-1445289.aspx
# /pages/feedback/pgid-1375917.aspx
# //www.shwapno.com
# javascript:void(0)
# https://www.shwapno.com/Registration/MyAccount.aspx?tabkey=Orders
# https://www.shwapno.com/Registration/MyAccount.aspx?tabkey=Profile
# https://www.shwapno.com/Registration/MyAccount.aspx?tabkey=Orders
# #!
# https://www.shwapno.com/Registration/MyAccount.aspx?tabkey=Wishlist
# https://www.shwapno.com/pages/buy-more-save-more/pgid-1320775.aspx
# https://www.shwapno.com/pages/hot-deals/pgid-1438735.aspx
# https://www.shwapno.com/pages/half-price-offers/pgid-1431195.aspx
# https://www.shwapno.com/pages/buy1-get1-offers/pgid-1427931.aspx
# ...

# %%
from bs4 import BeautifulSoup
with open("beautiful_soup_souping_the_page.html") as fp:
    soup = BeautifulSoup(fp)
    soup = BeautifulSoup("<html>data</html>")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-bf8c8553ea5f> in <module>
#       1 from bs4 import BeautifulSoup
# ----> 2 with open("beautiful_soup_souping_the_page.html") as fp:
#       3     soup = BeautifulSoup(fp)
#       4     soup = BeautifulSoup("<html>data</html>")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'beautiful_soup_souping_the_page.html'

# %%
import bs4
html = '''<b>tutorialspoint</b>, <i>&web scraping &data science;</i>'''
soup = bs4.BeautifulSoup(html, 'lxml')
print(soup)
# Out:
# <html><body><b>tutorialspoint</b>, <i>&amp;web scraping &amp;data science;</i></body></html>

# %%
##Tag: A HTML tag is used to define  various type of content. A tag object in BeautyfullSoup corresponds to an HTML or XML tag in 
#in the actual page or documents
from bs4 import BeautifulSoup
soup = BeautifulSoup('<b class="boldest">TutorialsPoint</b>')
tag = soup.html
type(tag)
tag.name

tag.name = "Strong"
tag  
#<Strong><body><b class="boldest">TutorialsPoint</b></body></Strong>
tag.name
# Out:
# 'Strong'

# %%
##Scrape IMDB movie rating and details using Python

# %%
from bs4 import BeautifulSoup
import requests
import re

# Downloading imdb top 250 movie's data
url = "http://www.imdb.com/chart/top"
req = requests.get(url)
soup = BeautifulSoup(req.text, "lxml")
movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

# %%
# create a empty list for storing
# movie information
list = []

# Iterating over movies to extract
# each movie's details
for index in range(0, len(movies)):
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    list.append(data)

# %%
for movie in list:
    print(movie['place'], '-', movie['movie_title'], '-', movie['year'],
          '-', movie['star_cast'], '-',movie['rating'])
# Out:
# 1 - The Shawshank Redemption - 1994 - Frank Darabont (dir.), Tim Robbins, Morgan Freeman - 9.220668489079944
# 2 - The Godfather - 1972 - Francis Ford Coppola (dir.), Marlon Brando, Al Pacino - 9.147454514817428
# 3 - The Godfather: Part II - 1974 - Francis Ford Coppola (dir.), Al Pacino, Robert De Niro - 8.980914668178462
# 4 - The Dark Knight - 2008 - Christopher Nolan (dir.), Christian Bale, Heath Ledger - 8.973953933335377
# 5 - 12 Angry Men - 1957 - Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb - 8.940283324772592
# 6 - Schindler's List - 1993 - Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes - 8.911474236462006
# 7 - The Lord of the Rings: The Return of the King - 2003 - Peter Jackson (dir.), Elijah Wood, Viggo Mortensen - 8.889345012339426
# 8 - Pulp Fiction - 1994 - Quentin Tarantino (dir.), John Travolta, Uma Thurman - 8.835275495427869
# 9 - Il buono, il brutto, il cattivo - 1966 - Sergio Leone (dir.), Clint Eastwood, Eli Wallach - 8.785667047495147
# ...
